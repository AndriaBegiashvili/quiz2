# %% [markdown]
# ## Columns
#
# age: age of primary beneficiary
#
# sex: insurance contractor gender, female, male
#
# bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height,
# objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9
#
# children: Number of children covered by health insurance / Number of dependents
#
# smoker: Smoking
#
# region: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.
#
# charges: Individual medical costs billed by health insurance
#
# ## DATA:
# https://www.kaggle.com/datasets/ultimus/football-salaries-dataset

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("raw_wages.csv")
df
# Out:
#                                    Name  \
# 0       Cristiano Ronaldo - Portuguese
# 1       Karim Benzema - French
# 2       Neymar - Brazilian
# 3       Ezri Konsa - English
# 4       Kylian Mbappé - French
# ...                                 ...
# 40786   - -
# 40787   - -
# 40788   - -
# 40789   - -
# 40790   - -
#
#                                             Club  \
# 0       Al-Nassr (KSA) - Roshn Saudi League
# 1       Al-Ittihad - Roshn Saudi League
# 2       Al-Hilal (KSA) - Roshn Saudi League
# 3       Al-Hilal (KSA) - Roshn Saudi League
# 4       Paris Saint-Germain - Ligue 1 Uber Eats
# ...                                          ...
# 40786   -
# 40787   -
# 40788   -
# 40789   -
# 40790   -
#
#                                                 Division  \
# 0       Roshn Saudi League                           ...
# 1       Roshn Saudi League                           ...
# 2       Roshn Saudi League                           ...
# ...

# %%
df.isnull().sum()
# Out:
# Name               0
# Club               0
# Division           0
# Based              0
# Nat                0
# EU National        0
# Caps               0
# AT Apps            0
# Position           0
# Age                0
# CR                 0
# Begins             0
# Expires            0
# Last Club          0
# Last Trans. Fee    0
# Salary             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 152

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                Caps           Age
# count  40639.000000  40639.000000
# mean       5.163021     25.207239
# std       13.687488      5.315506
# min        0.000000     17.000000
# 25%        0.000000     21.000000
# 50%        0.000000     25.000000
# 75%        3.000000     29.000000
# max      200.000000     45.000000

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
le = LabelEncoder()
df['Nat'] = le.fit_transform(df['Nat'])

# %%
df
# Out:
#                                    Name  \
# 0       Cristiano Ronaldo - Portuguese
# 1       Karim Benzema - French
# 2       Neymar - Brazilian
# 3       Ezri Konsa - English
# 4       Kylian Mbappé - French
# ...                                 ...
# 40786   - -
# 40787   - -
# 40788   - -
# 40789   - -
# 40790   - -
#
#                                             Club  \
# 0       Al-Nassr (KSA) - Roshn Saudi League
# 1       Al-Ittihad - Roshn Saudi League
# 2       Al-Hilal (KSA) - Roshn Saudi League
# 3       Al-Hilal (KSA) - Roshn Saudi League
# 4       Paris Saint-Germain - Ligue 1 Uber Eats
# ...                                          ...
# 40786   -
# 40787   -
# 40788   -
# 40789   -
# 40790   -
#
#                                                 Division  \
# 0       Roshn Saudi League                           ...
# 1       Roshn Saudi League                           ...
# 2       Roshn Saudi League                           ...
# ...

# %%
df = pd.get_dummies(df, columns=['Division'])

# %%
df
# Out:
#                                    Name  \
# 0       Cristiano Ronaldo - Portuguese
# 1       Karim Benzema - French
# 2       Neymar - Brazilian
# 3       Ezri Konsa - English
# 4       Kylian Mbappé - French
# ...                                 ...
# 40786   - -
# 40787   - -
# 40788   - -
# 40789   - -
# 40790   - -
#
#                                             Club  \
# 0       Al-Nassr (KSA) - Roshn Saudi League
# 1       Al-Ittihad - Roshn Saudi League
# 2       Al-Hilal (KSA) - Roshn Saudi League
# 3       Al-Hilal (KSA) - Roshn Saudi League
# 4       Paris Saint-Germain - Ligue 1 Uber Eats
# ...                                          ...
# 40786   -
# 40787   -
# 40788   -
# 40789   -
# 40790   -
#
#                                                    Based  Nat    EU National  \
# 0       Saudi Arabia (Saudi Pro League)              ...  155   Yes
# 1       Saudi Arabia (Saudi Pro League)              ...   66   Yes
# ...

# %%
X_train
# Out:
# 0        38.0
# 1        35.0
# 2        31.0
# 3        25.0
# 4        24.0
#          ...
# 40786    31.0
# 40787    21.0
# 40788    24.0
# 40789    20.0
# 40790    17.0
# Name: Age, Length: 40639, dtype: float64

# %%
# Evaluate the model on training data
train_score = linear_reg_model.score(X_train, y_train)
print("Training R^2 Score:", train_score)

# Evaluate the model on validation data
val_score = linear_reg_model.score(X_val, y_val)
print("Validation R^2 Score:", val_score)
# Out:
# Training R^2 Score: 0.7299057809339075
# Validation R^2 Score: 0.8069287081198013

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(121)
sns.scatterplot(x='age',y='salary',data=df,palette='magma',hue='salary',ax=ax)
ax.set_title('Scatter plot of Charges vs age')

ax = f.add_subplot(122)
sns.scatterplot(x='bmi',y='charges',data=df,palette='viridis',hue='smoker')
ax.set_title('Scatter plot of Charges vs bmi')
